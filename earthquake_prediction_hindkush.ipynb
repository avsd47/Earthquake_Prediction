# %% [markdown]
# <a href="https://colab.research.google.com/github/avsd47/Earthquake_Prediction/blob/main/earthquake_prediction_hindkush.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **EARTHQUAKE PREDICTION**

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
pip install skfeature-chappers
# Out:
# Collecting skfeature-chappers
#   Downloading https://files.pythonhosted.org/packages/e6/45/19bb801eb3b4a892534ab86468ad0669a68ff63578610f90051190e3622f/skfeature-chappers-1.0.3.tar.gz
# Building wheels for collected packages: skfeature-chappers
#   Building wheel for skfeature-chappers (setup.py) ... done
#   Created wheel for skfeature-chappers: filename=skfeature_chappers-1.0.3-py2.py3-none-any.whl size=59510 sha256=52344b28fc690f521dbd0ffd3c7fcb57096c5549d6ef7acd3adc22f7a502585c
#   Stored in directory: /root/.cache/pip/wheels/ac/61/bf/1b3a8c232a0072409508c2ec4c12f316e95681ae72ba7315d2
# Successfully built skfeature-chappers
# Installing collected packages: skfeature-chappers
# Successfully installed skfeature-chappers-1.0.3

# %% [markdown]
# ## **HINDKUSH**

# %%
hind_df = pd.read_excel("hindkush.xls")
hind_df.head()
# Out:
#    T_Days     b_lik     a_lik  ...    x7_lsq  Actual Mag  Lable (>=5)
# 0     355  0.772766  4.790034  ...  0.000236         5.5            Y
# 1     354  0.775526  4.801073  ...  0.000230         5.5            Y
# 2     344  0.753983  4.714904  ...  0.000435         4.6            N
# 3     347  0.764603  4.757382  ...  0.000413         0.0            N
# 4     350  0.764603  4.757382  ...  0.000413         5.1            Y
#
# [5 rows x 62 columns]

# %%
hind_df = hind_df[hind_df["Actual Mag"]>4.0] #Applying cutoff magnitude

# %%
def label(row):
    if row["Actual Mag"] >5:  #Threshold magnitude
        return 1
    else:
        return 0

# %%
hind_df['mag'] = hind_df.apply (lambda row: label(row), axis=1) #Applying threshold on hind dataset

# %%
pd.options.display.max_rows = 400
hind_df.isnull().sum()
# Out:
# T_Days          0
# b_lik           0
# a_lik           0
# b_lsq           0
# a_lsq           0
# std_b_lik       0
# std_b_lsq       0
# T_Rec_lik4.0    0
# T_Rec_lik4.1    0
# T_Rec_lik4.2    0
# T_Rec_lik4.3    0
# T_Rec_lik4.4    0
# T_Rec_lik4.5    0
# T_Rec_lik4.6    0
# T_Rec_lik4.7    0
# T_Rec_lik4.8    0
# T_Rec_lik4.9    0
# T_Rec_lik5.0    0
# T_Rec_lik5.1    0
# T_Rec_lik5.2    0
# T_Rec_lik5.3    0
# T_Rec_lik5.4    0
# T_Rec_lik5.5    0
# T_Rec_lik5.6    0
# T_Rec_lik5.7    0
# T_Rec_lik5.8    0
# T_Rec_lik5.9    0
# T_Rec_lik6.0    0
# T_Rec_lsq4.0    0
# T_Rec_lsq4.1    0
# T_Rec_lsq4.2    0
# T_Rec_lsq4.3    0
# T_Rec_lsq4.4    0
# T_Rec_lsq4.5    0
# T_Rec_lsq4.6    0
# T_Rec_lsq4.7    0
# T_Rec_lsq4.8    0
# T_Rec_lsq4.9    0
# T_Rec_lsq5.0    0
# T_Rec_lsq5.1    0
# T_Rec_lsq5.2    0
# T_lsq_lsq5.3    0
# T_Rec_lsq5.4    0
# T_Rec_lsq5.5    0
# T_Rec_lsq5.6    0
# T_Rec_lsq5.7    0
# T_Rec_lsq5.8    0
# T_Rec_lsq5.9    0
# T_Rec_lsq6.0    0
# Beta Value      0
# Z Value         0
# Mean_Mag        0
# Energy          0
# M_def_Lik       0
# M_def_lsq       0
# NU_mlik         0
# NU_lsq          0
# x6              0
# x7_mlk          0
# x7_lsq          0
# Actual Mag      0
# Lable (>=5)     0
# mag             0
# dtype: int64

# %%
hind_df = hind_df.dropna()

# %%
pd.options.display.max_rows = 400
hind_df.isnull().sum()
# Out:
# T_Days          0
# b_lik           0
# a_lik           0
# b_lsq           0
# a_lsq           0
# std_b_lik       0
# std_b_lsq       0
# T_Rec_lik4.0    0
# T_Rec_lik4.1    0
# T_Rec_lik4.2    0
# T_Rec_lik4.3    0
# T_Rec_lik4.4    0
# T_Rec_lik4.5    0
# T_Rec_lik4.6    0
# T_Rec_lik4.7    0
# T_Rec_lik4.8    0
# T_Rec_lik4.9    0
# T_Rec_lik5.0    0
# T_Rec_lik5.1    0
# T_Rec_lik5.2    0
# T_Rec_lik5.3    0
# T_Rec_lik5.4    0
# T_Rec_lik5.5    0
# T_Rec_lik5.6    0
# T_Rec_lik5.7    0
# T_Rec_lik5.8    0
# T_Rec_lik5.9    0
# T_Rec_lik6.0    0
# T_Rec_lsq4.0    0
# T_Rec_lsq4.1    0
# T_Rec_lsq4.2    0
# T_Rec_lsq4.3    0
# T_Rec_lsq4.4    0
# T_Rec_lsq4.5    0
# T_Rec_lsq4.6    0
# T_Rec_lsq4.7    0
# T_Rec_lsq4.8    0
# T_Rec_lsq4.9    0
# T_Rec_lsq5.0    0
# T_Rec_lsq5.1    0
# T_Rec_lsq5.2    0
# T_lsq_lsq5.3    0
# T_Rec_lsq5.4    0
# T_Rec_lsq5.5    0
# T_Rec_lsq5.6    0
# T_Rec_lsq5.7    0
# T_Rec_lsq5.8    0
# T_Rec_lsq5.9    0
# T_Rec_lsq6.0    0
# Beta Value      0
# Z Value         0
# Mean_Mag        0
# Energy          0
# M_def_Lik       0
# M_def_lsq       0
# NU_mlik         0
# NU_lsq          0
# x6              0
# x7_mlk          0
# x7_lsq          0
# Actual Mag      0
# Lable (>=5)     0
# mag             0
# dtype: int64

# %%
features = hind_df.iloc[:,0:60].to_numpy()
target = hind_df["mag"].to_numpy()

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(features)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
hind_df.describe()
# Out:
#             T_Days        b_lik  ...   Actual Mag          mag
# count  4245.000000  4245.000000  ...  4245.000000  4245.000000
# mean    144.288339     1.058247  ...     4.911284     0.265960
# std      71.582995     0.289225  ...     0.508534     0.441895
# min      22.000000     0.571440  ...     4.100000     0.000000
# 25%      87.000000     0.816343  ...     4.600000     0.000000
# 50%     134.000000     1.029134  ...     4.800000     0.000000
# 75%     191.000000     1.255186  ...     5.100000     1.000000
# max     395.000000     2.648137  ...     7.500000     1.000000
#
# [8 rows x 62 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, y_train, X_test, y_test = train_test_split(features,target, test_size = 0.3,random_state =1)

# %% [markdown]
# **LOGISTIC** **REGRESSION**

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,X_test)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred = lr.predict(y_train)
from sklearn.metrics import matthews_corrcoef,accuracy_score
print('Accuracy: ',accuracy_score(y_test, pred)*100,'%')
print('MCC score: ',matthews_corrcoef(y_test, pred))
# Out:
# Accuracy:  72.8414442700157 %
# MCC score:  0.0

# %%
plt.figure(figsize = (14,14))
plt.title('correlation')
corr = hind_df.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,linewidths=.1,cmap="Reds")
plt.show()

# %% [markdown]
# **RANDOM FOREST**

# %%
from sklearn.ensemble import RandomForestClassifier
rf =  RandomForestClassifier(n_estimators=100, n_jobs=-1)
rf.fit(X_train,X_test)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)

# %%
pred = rf.predict(y_train)
from sklearn.metrics import matthews_corrcoef,accuracy_score
print('Accuracy: ',accuracy_score(y_test, pred)*100,'%')
print('MCC score: ',matthews_corrcoef(y_test, pred))
# Out:
# Accuracy:  87.28414442700158 %
# MCC score:  0.6648895282843952

# %% [markdown]
# **XGBOOST**

# %%
MAX_ROUNDS = 1000
EARLY_STOP = 50
from xgboost import XGBClassifier
xg = XGBClassifier(MAX_ROUNDS,early_stopping_rounds=EARLY_STOP,maximize=True)
xg.fit(X_train,X_test)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, early_stopping_rounds=50,
#               gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=1000,
#               maximize=True, min_child_weight=1, missing=None, n_estimators=100,
#               n_jobs=1, nthread=None, objective='binary:logistic',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=None, silent=None, subsample=1, verbosity=1)

# %%
pred = xg.predict(y_train)
from sklearn.metrics import matthews_corrcoef,accuracy_score
print('Accuracy: ',accuracy_score(y_test, pred)*100,'%')
print('MCC score: ',matthews_corrcoef(y_test, pred))
# Out:
# Accuracy:  88.30455259026687 %
# MCC score:  0.6954802834442811

# %% [markdown]
# **PCA WITH LOGISTIC REGRESSION**

# %%
from sklearn.decomposition import PCA
from statistics import mean
from sklearn.metrics import matthews_corrcoef,accuracy_score
avgaccs=[]
avgmccs=[]
for i in range(1,61):
  pca=PCA(n_components=i)
  pca.fit(features)
  x_pca=pca.transform(features)
  acc,mcc=[],[]
  for j in range(0,10):
    X_train, y_train, X_test, y_test = train_test_split(x_pca,target, test_size = 0.3,stratify=target)
    lr = LogisticRegression()
    lr.fit(X_train,X_test)
    pred = lr.predict(y_train)
    acc.append(accuracy_score(y_test, pred))
    mcc.append(matthews_corrcoef(y_test, pred))
  print('For ',i,'number of features: ',round(mean(acc),4)*100,round(mean(mcc),4))
  avgaccs.append(round(mean(acc),4)*100)
  avgmccs.append(round(mean(mcc),4))
print(max(avgaccs))
print(avgaccs.index(max(avgaccs)))
# Out:
# For  1 number of features:  62.529999999999994 0.0731
# For  2 number of features:  63.239999999999995 0.0867
# For  3 number of features:  63.5 0.0958
# For  4 number of features:  63.04 0.0886
# For  5 number of features:  63.55 0.0932
# For  6 number of features:  62.81 0.0808
# For  7 number of features:  62.970000000000006 0.0878
# For  8 number of features:  62.96000000000001 0.0852
# For  9 number of features:  63.65 0.1021
# For  10 number of features:  63.800000000000004 0.1051
# For  11 number of features:  63.129999999999995 0.0882
# For  12 number of features:  63.1 0.0891
# For  13 number of features:  63.339999999999996 0.0938
# For  14 number of features:  63.2 0.0898
# For  15 number of features:  63.01 0.0814
# For  16 number of features:  63.38 0.0969
# For  17 number of features:  62.8 0.0805
# For  18 number of features:  62.53999999999999 0.0672
# For  19 number of features:  62.739999999999995 0.0752
# For  20 number of features:  62.83 0.0752
# For  21 number of features:  63.260000000000005 0.0904
# For  22 number of features:  63.660000000000004 0.1003
# For  23 number of features:  63.05 0.0857
# For  24 number of features:  62.57 0.0762
# For  25 number of features:  62.760000000000005 0.0763
# For  26 number of features:  63.0 0.0805
# For  27 number of features:  62.8 0.0804
# For  28 number of features:  62.67 0.0779
# For  29 number of features:  63.06 0.0862
# For  30 number of features:  62.55 0.0738
# For  31 number of features:  62.67 0.0755
# For  32 number of features:  63.23 0.092
# For  33 number of features:  62.870000000000005 0.0862
# For  34 number of features:  63.239999999999995 0.0901
# For  35 number of features:  63.339999999999996 0.0958
# For  36 number of features:  62.839999999999996 0.0825
# For  37 number of features:  63.11 0.0905
# For  38 number of features:  62.970000000000006 0.0788
# For  39 number of features:  63.190000000000005 0.0938
# For  40 number of features:  62.86000000000001 0.0868
# For  41 number of features:  63.019999999999996 0.0861
# For  42 number of features:  62.949999999999996 0.0809
# For  43 number of features:  63.239999999999995 0.0924
# For  44 number of features:  62.970000000000006 0.0852
# For  45 number of features:  63.29 0.0927
# For  46 number of features:  63.01 0.0853
# For  47 number of features:  62.260000000000005 0.0703
# For  48 number of features:  62.67 0.0763
# For  49 number of features:  62.74999999999999 0.0781
# For  50 number of features:  62.839999999999996 0.0858
# For  51 number of features:  63.2 0.0886
# For  52 number of features:  62.79 0.0818
# For  53 number of features:  62.43 0.0721
# For  54 number of features:  62.46000000000001 0.0694
# For  55 number of features:  62.41 0.0724
# For  56 number of features:  63.54 0.1029
# For  57 number of features:  62.81 0.0763
# For  58 number of features:  62.53999999999999 0.0758
# For  59 number of features:  63.029999999999994 0.0856
# For  60 number of features:  62.96000000000001 0.0845
# 63.800000000000004
# 9

# %%
pca=PCA(n_components=10) #Using 10 features for PCA
pca.fit(features)
x_pca=pca.transform(features)
X_train, y_train, X_test, y_test = train_test_split(x_pca,target, test_size = 0.3,random_state=1)

# %%
  lr = LogisticRegression()
  lr.fit(X_train,X_test)
  pred = lr.predict(y_train)
  from sklearn.metrics import matthews_corrcoef,accuracy_score
print('Accuracy: ',accuracy_score(y_test, pred)*100,'%')
print('MCC score: ',matthews_corrcoef(y_test, pred))
# Out:
# Accuracy:  62.95133437990581 %
# MCC score:  0.08691035985301208

# %% [markdown]
# **PCA WITH RANDOM FOREST**

# %%
from sklearn.decomposition import PCA
from statistics import mean
avgaccs=[]
avgmccs=[]
for i in range(1,61):
  pca=PCA(n_components=i)
  pca.fit(features)
  x_pca=pca.transform(features)
  acc,mcc=[],[]
  for j in range(0,10):
    X_train, y_train, X_test, y_test = train_test_split(x_pca,target, test_size = 0.3,stratify=target)
    rf =  RandomForestClassifier(n_estimators=100, n_jobs=-1)
    rf.fit(X_train,X_test)
    pred = rf.predict(y_train)
    acc.append(accuracy_score(y_test, pred))
    mcc.append(matthews_corrcoef(y_test, pred))
  print('For ',i,'number of features: ',round(mean(acc),4)*100,round(mean(mcc),4))
  avgaccs.append(round(mean(acc),4)*100)
  avgmccs.append(round(mean(mcc),4))
print(max(avgaccs))
print(avgaccs.index(max(avgaccs)))
# Out:
# For  1 number of features:  62.91 0.051
# For  2 number of features:  72.89 0.2325
# For  3 number of features:  80.81 0.4683
# For  4 number of features:  82.83 0.5307
# For  5 number of features:  84.07 0.5691
# For  6 number of features:  85.68 0.6129
# For  7 number of features:  85.77 0.615
# For  8 number of features:  87.06 0.6516
# For  9 number of features:  87.57000000000001 0.6679
# For  10 number of features:  87.8 0.6746
# For  11 number of features:  88.06 0.6811
# For  12 number of features:  89.02 0.7083
# For  13 number of features:  88.49000000000001 0.6921
# For  14 number of features:  88.66000000000001 0.6969
# For  15 number of features:  89.14999999999999 0.7107
# For  16 number of features:  89.03 0.7077
# For  17 number of features:  88.64999999999999 0.6975
# For  18 number of features:  88.81 0.7016
# For  19 number of features:  89.01 0.7069
# For  20 number of features:  88.71 0.6984
# For  21 number of features:  88.57000000000001 0.6948
# For  22 number of features:  89.13 0.7102
# For  23 number of features:  89.46 0.7195
# For  24 number of features:  89.0 0.7069
# For  25 number of features:  89.11 0.7099
# For  26 number of features:  88.8 0.7009
# For  27 number of features:  89.01 0.7068
# For  28 number of features:  89.47 0.7201
# For  29 number of features:  89.13 0.7107
# For  30 number of features:  89.29 0.7148
# For  31 number of features:  89.2 0.7122
# For  32 number of features:  88.92 0.7042
# For  33 number of features:  89.58 0.7232
# For  34 number of features:  88.92 0.7044
# For  35 number of features:  89.82 0.7295
# For  36 number of features:  89.53999999999999 0.7219
# For  37 number of features:  89.59 0.7233
# For  38 number of features:  89.60000000000001 0.7237
# For  39 number of features:  89.29 0.7151
# For  40 number of features:  89.60000000000001 0.7235
# For  41 number of features:  89.25 0.7135
# For  42 number of features:  89.32 0.7156
# For  43 number of features:  89.36 0.7168
# For  44 number of features:  89.13 0.7101
# For  45 number of features:  89.96 0.7334
# For  46 number of features:  89.25 0.7136
# For  47 number of features:  89.87 0.7308
# For  48 number of features:  89.51 0.7217
# For  49 number of features:  89.4 0.7177
# For  50 number of features:  89.25 0.714
# For  51 number of features:  89.52 0.7217
# For  52 number of features:  89.49000000000001 0.7204
# For  53 number of features:  89.22 0.7125
# For  54 number of features:  89.32 0.7156
# For  55 number of features:  89.79 0.7287
# For  56 number of features:  89.44 0.7193
# For  57 number of features:  89.03 0.7076
# For  58 number of features:  89.32 0.7157
# For  59 number of features:  89.22 0.7127
# For  60 number of features:  89.25999999999999 0.7143
# 89.96
# 44

# %%
pca=PCA(n_components=45) #Using 45 features for PCA
pca.fit(features)
x_pca=pca.transform(features)
X_train, y_train, X_test, y_test = train_test_split(x_pca,target, test_size = 0.3,random_state=1)

# %%
rf =  RandomForestClassifier(n_estimators=100, n_jobs=-1)
rf.fit(X_train,X_test)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)

# %%
pred = rf.predict(y_train)
from sklearn.metrics import matthews_corrcoef,accuracy_score
print('Accuracy: ',accuracy_score(y_test, pred)*100,'%')
print('MCC score: ',matthews_corrcoef(y_test, pred))
# Out:
# Accuracy:  89.1679748822606 %
# MCC score:  0.7166979351894613

# %% [markdown]
# **PCA WITH XGBOOST**

# %%
from sklearn.decomposition import PCA
from statistics import mean
avgaccs=[]
avgmccs=[]
for i in range(1,60):
  pca=PCA(n_components=i)
  pca.fit(features)
  x_pca=pca.transform(features)
  acc,mcc=[],[]
  for j in range(0,10):
    X_train, y_train, X_test, y_test = train_test_split(x_pca,target, test_size = 0.3,stratify=target)
    xg = XGBClassifier(MAX_ROUNDS,early_stopping_rounds=EARLY_STOP,maximize=True)
    xg.fit(X_train,X_test)
    pred = xg.predict(y_train)
    acc.append(accuracy_score(y_test, pred))
    mcc.append(matthews_corrcoef(y_test, pred))
  print('For ',i,'number of features: ',round(mean(acc),4)*100,round(mean(mcc),4))
  avgaccs.append(round(mean(acc),4)*100)
  avgmccs.append(round(mean(mcc),4))
print(max(avgaccs))
print(avgaccs.index(max(avgaccs)))
# Out:
# For  1 number of features:  66.60000000000001 0.0541
# For  2 number of features:  71.94 0.2226
# For  3 number of features:  80.39 0.4637
# For  4 number of features:  82.39999999999999 0.5239
# For  5 number of features:  83.84 0.563
# For  6 number of features:  85.2 0.6039
# For  7 number of features:  85.89 0.6229
# For  8 number of features:  86.95 0.6524
# For  9 number of features:  87.51 0.667
# For  10 number of features:  88.52 0.697
# For  11 number of features:  88.53999999999999 0.6962
# For  12 number of features:  88.63 0.7003
# For  13 number of features:  88.83 0.7033
# For  14 number of features:  89.39 0.7186
# For  15 number of features:  89.14 0.7121
# For  16 number of features:  88.59 0.6973
# For  17 number of features:  89.24 0.7145
# For  18 number of features:  89.75999999999999 0.7293
# For  19 number of features:  89.66 0.7262
# For  20 number of features:  89.69 0.7266
# For  21 number of features:  89.8 0.7303
# For  22 number of features:  89.82 0.7304
# For  23 number of features:  89.84 0.7309
# For  24 number of features:  89.84 0.7312
# For  25 number of features:  89.66 0.7262
# For  26 number of features:  89.63 0.7255
# For  27 number of features:  89.62 0.726
# For  28 number of features:  89.53 0.7231
# For  29 number of features:  89.89 0.733
# For  30 number of features:  89.89 0.7327
# For  31 number of features:  89.51 0.7213
# For  32 number of features:  89.53999999999999 0.7238
# For  33 number of features:  89.8 0.7305
# For  34 number of features:  89.86 0.732
# For  35 number of features:  89.87 0.7319
# For  36 number of features:  89.56 0.7235
# For  37 number of features:  89.75999999999999 0.7295
# For  38 number of features:  89.98 0.7348
# For  39 number of features:  90.13 0.7389
# For  40 number of features:  89.52 0.7232
# For  41 number of features:  89.36 0.7188
# For  42 number of features:  89.53 0.7224
# For  43 number of features:  89.85 0.7313
# For  44 number of features:  90.0 0.7356
# For  45 number of features:  89.47 0.7215
# For  46 number of features:  89.95 0.7343
# For  47 number of features:  90.02 0.7357
# For  48 number of features:  90.05 0.7373
# For  49 number of features:  90.03 0.7365
# For  50 number of features:  89.68 0.7265
# For  51 number of features:  89.68 0.7264
# For  52 number of features:  89.74 0.7282
# For  53 number of features:  89.73 0.7276
# For  54 number of features:  89.66 0.7266
# For  55 number of features:  89.82 0.7306
# For  56 number of features:  89.85 0.7323
# For  57 number of features:  90.34 0.7451
# For  58 number of features:  89.91 0.7336
# For  59 number of features:  89.95 0.7339
# 90.34
# 56

# %%
pca=PCA(n_components=39) #Using 39 features for PCA
pca.fit(features)
x_pca=pca.transform(features)
X_train, y_train, X_test, y_test = train_test_split(x_pca,target, test_size = 0.3,random_state=1)

# %%
xg = XGBClassifier(MAX_ROUNDS,early_stopping_rounds=EARLY_STOP,maximize=True)
xg.fit(X_train,X_test)
pred = xg.predict(y_train)
from sklearn.metrics import matthews_corrcoef,accuracy_score
print('Accuracy: ',accuracy_score(y_test, pred)*100,'%')
print('MCC score: ',matthews_corrcoef(y_test, pred))
# Out:
# Accuracy:  88.93249607535321 %
# MCC score:  0.7126257944947471

# %% [markdown]
# **MRMR WITH XGBOOST**

# %%
from skfeature.function.information_theoretical_based import LCSI
def mrmr(X, y,i,**kwargs):
    """
    This function implements the MRMR feature selection
    Input
    -----
    X: {numpy array}, shape (n_samples, n_features)
        input data, guaranteed to be discrete
    y: {numpy array}, shape (n_samples,)
        input class labels
    kwargs: {dictionary}
        n_selected_features: {int}
            number of features to select
    Output
    ------
    F: {numpy array}, shape (n_features,)
        index of selected features, F[0] is the most important feature
    J_CMI: {numpy array}, shape: (n_features,)
        corresponding objective function value of selected features
    MIfy: {numpy array}, shape: (n_features,)
        corresponding mutual information between selected features and response
    Reference
    ---------
    Brown, Gavin et al. "Conditional Likelihood Maximisation: A Unifying Framework for Information Theoretic Feature Selection." JMLR 2012.
    """
    if 'n_selected_features' in kwargs.keys():
        n_selected_features = kwargs['n_selected_features']
        F, J_CMI, MIfy = LCSI.lcsi(X, y, gamma=0, function_name='MRMR', n_selected_features=n_selected_features)
    else:
        F, J_CMI, MIfy = LCSI.lcsi(X, y, gamma=0, function_name='MRMR', n_selected_features=i)
    return F

# %%
X_train, y_train, X_test, y_test = train_test_split(features,target, test_size = 0.3,random_state=1)

# %%
F = mrmr(X_train,X_test,60)
print(F)
# Out:
# [28 57 51  0 49  1  7  2 58 50 53  3 59  4 54  8 56  6  5 55  9 11 16 12
#  13 10 15 48 14 44 17 41 43 27 38 23 29 18 30 26 31 21 32 19 33 20 34 22
#  35 24 36 25 37 39 40 42 45 46 47 52]

# %%
acc = []
mcc=[]
MAX_ROUNDS = 1000 #lgb iterations
EARLY_STOP = 50
for i in range(1,61):
  features2 = hind_df.iloc[:,F[0:i]].to_numpy()
  #print(features2.shape)
  X_train, y_train, X_test, y_test = train_test_split(features2,target, test_size = 0.3)
  print(X_train.shape,X_test.shape)
  from xgboost import XGBClassifier
  xg = XGBClassifier(MAX_ROUNDS,early_stopping_rounds=EARLY_STOP,maximize=True)
  xg.fit(X_train,X_test)
  pred = xg.predict(y_train)
  from sklearn.metrics import accuracy_score,confusion_matrix,r2_score
  from sklearn.metrics import matthews_corrcoef
  print(accuracy_score(y_test, pred), matthews_corrcoef(y_test, pred))
  acc.append(accuracy_score(y_test, pred))
  mcc.append(matthews_corrcoef(y_test, pred))
print(acc)
print(max(acc))
print(acc.index(max(acc)))
print(mcc[acc.index(max(acc))])
# Out:
# (2971, 1) (2971,)
# 0.67425431711146 0.07741678796753612
# (2971, 2) (2971,)
# 0.7315541601255887 0.24965605880094008
# (2971, 3) (2971,)
# 0.8108320251177394 0.4748152807854927
# (2971, 4) (2971,)
# 0.8430141287284144 0.5652690515016054
# (2971, 5) (2971,)
# 0.8461538461538461 0.5897274552610904
# (2971, 6) (2971,)
# 0.8304552590266876 0.5520513498812057
# (2971, 7) (2971,)
# 0.8328100470957613 0.53822272283339
# (2971, 8) (2971,)
# 0.8335949764521193 0.5647625441510504
# (2971, 9) (2971,)
# 0.8430141287284144 0.5576028518186036
# (2971, 10) (2971,)
# 0.8406593406593407 0.5821918119678645
# (2971, 11) (2971,)
# 0.8571428571428571 0.615854875701525
# (2971, 12) (2971,)
# 0.8751962323390895 0.661922408730449
# (2971, 13) (2971,)
# 0.8830455259026687 0.6812134749363742
# (2971, 14) (2971,)
# 0.8673469387755102 0.6557626812914055
# (2971, 15) (2971,)
# 0.8963893249607535 0.726637922044828
# (2971, 16) (2971,)
# 0.8704866562009419 0.6646926625174626
# (2971, 17) (2971,)
# 0.8885400313971743 0.7076965199565829
# (2971, 18) (2971,)
# 0.9050235478806907 0.7485551098318114
# (2971, 19) (2971,)
# 0.8971742543171115 0.7143246391659563
# (2971, 20) (2971,)
# 0.8759811616954474 0.6650076613654613
# (2971, 21) (2971,)
# 0.8948194662480377 0.7256596612014934
# (2971, 22) (2971,)
# 0.8901098901098901 0.7187116503636841
# (2971, 23) (2971,)
# 0.8948194662480377 0.731670676841188
# (2971, 24) (2971,)
# 0.8987441130298273 0.7306031436165468
# (2971, 25) (2971,)
# 0.8869701726844584 0.6969420341747129
# (2971, 26) (2971,)
# 0.8932496075353218 0.7109925136463026
# (2971, 27) (2971,)
# 0.8861852433281004 0.710324260348408
# (2971, 28) (2971,)
# 0.9042386185243328 0.7424759826130359
# (2971, 29) (2971,)
# 0.8877551020408163 0.7110925891469805
# (2971, 30) (2971,)
# 0.8916797488226059 0.7068741769739514
# (2971, 31) (2971,)
# 0.8956043956043956 0.7139161390936898
# (2971, 32) (2971,)
# 0.8987441130298273 0.7252652467799402
# (2971, 33) (2971,)
# 0.902668759811617 0.7393059923641396
# (2971, 34) (2971,)
# 0.8869701726844584 0.6906528003797952
# (2971, 35) (2971,)
# 0.9144427001569859 0.7700050658394655
# (2971, 36) (2971,)
# 0.8877551020408163 0.7061306921665838
# (2971, 37) (2971,)
# 0.9081632653061225 0.7597170702222827
# (2971, 38) (2971,)
# 0.8775510204081632 0.6637348501258257
# (2971, 39) (2971,)
# 0.8838304552590267 0.6989695330305251
# (2971, 40) (2971,)
# 0.8854003139717426 0.6905414825032281
# (2971, 41) (2971,)
# 0.9105180533751962 0.7503324267119161
# (2971, 42) (2971,)
# 0.8877551020408163 0.7060935540468961
# (2971, 43) (2971,)
# 0.8869701726844584 0.6975147831256764
# (2971, 44) (2971,)
# 0.9058084772370487 0.7433065447638247
# (2971, 45) (2971,)
# 0.8971742543171115 0.728600167668864
# (2971, 46) (2971,)
# 0.9010989010989011 0.7519308434869194
# (2971, 47) (2971,)
# 0.9010989010989011 0.7250391572835276
# (2971, 48) (2971,)
# 0.9034536891679749 0.7449479598968717
# (2971, 49) (2971,)
# 0.8916797488226059 0.7184250890314456
# (2971, 50) (2971,)
# 0.8877551020408163 0.699904979897059
# (2971, 51) (2971,)
# 0.8838304552590267 0.6802878669364204
# (2971, 52) (2971,)
# 0.8901098901098901 0.6995457945932735
# (2971, 53) (2971,)
# 0.8854003139717426 0.6999007962533577
# (2971, 54) (2971,)
# 0.8948194662480377 0.7133830230113055
# (2971, 55) (2971,)
# 0.8956043956043956 0.7248299475398874
# (2971, 56) (2971,)
# 0.8869701726844584 0.6959744695466095
# (2971, 57) (2971,)
# 0.8861852433281004 0.6952413058419007
# (2971, 58) (2971,)
# 0.8759811616954474 0.6857933051563063
# (2971, 59) (2971,)
# 0.9089481946624803 0.7540345857936185
# (2971, 60) (2971,)
# 0.8979591836734694 0.7260401972927639
# [0.67425431711146, 0.7315541601255887, 0.8108320251177394, 0.8430141287284144, 0.8461538461538461, 0.8304552590266876, 0.8328100470957613, 0.8335949764521193, 0.8430141287284144, 0.8406593406593407, 0.8571428571428571, 0.8751962323390895, 0.8830455259026687, 0.8673469387755102, 0.8963893249607535, 0.8704866562009419, 0.8885400313971743, 0.9050235478806907, 0.8971742543171115, 0.8759811616954474, 0.8948194662480377, 0.8901098901098901, 0.8948194662480377, 0.8987441130298273, 0.8869701726844584, 0.8932496075353218, 0.8861852433281004, 0.9042386185243328, 0.8877551020408163, 0.8916797488226059, 0.8956043956043956, 0.8987441130298273, 0.902668759811617, 0.8869701726844584, 0.9144427001569859, 0.8877551020408163, 0.9081632653061225, 0.8775510204081632, 0.8838304552590267, 0.8854003139717426, 0.9105180533751962, 0.8877551020408163, 0.8869701726844584, 0.9058084772370487, 0.8971742543171115, 0.9010989010989011, 0.9010989010989011, 0.9034536891679749, 0.8916797488226059, 0.8877551020408163, 0.8838304552590267, 0.8901098901098901, 0.8854003139717426, 0.8948194662480377, 0.8956043956043956, 0.8869701726844584, 0.8861852433281004, 0.8759811616954474, 0.9089481946624803, 0.8979591836734694]
# 0.9144427001569859
# 34
# 0.7700050658394655

# %%
acc = []
mcc=[]
MAX_ROUNDS = 2000 #lgb iterations
EARLY_STOP = 50
for i in range(1,10):
  features2 = hind_df.iloc[:,F[0:35]].to_numpy()
  print(features2.shape)
  X_train, y_train, X_test, y_test = train_test_split(features2,target, test_size = 0.3)
  print(X_train.shape,X_test.shape)
  from xgboost import XGBClassifier
  xg = XGBClassifier(MAX_ROUNDS,early_stopping_rounds=EARLY_STOP,maximize=True)
  xg.fit(X_train,X_test)
  pred = xg.predict(y_train)
  from sklearn.metrics import accuracy_score,confusion_matrix,r2_score
  from sklearn.metrics import matthews_corrcoef
  print(accuracy_score(y_test, pred), matthews_corrcoef(y_test, pred))
  acc.append(accuracy_score(y_test, pred))
  mcc.append(matthews_corrcoef(y_test, pred))
print(acc)
print(max(acc))
print(acc.index(max(acc)))
print(mcc[acc.index(max(acc))])
# Out:
# (4245, 35)
# (2971, 35) (2971,)
# 0.8924646781789639 0.7117934422494234
# (4245, 35)
# (2971, 35) (2971,)
# 0.8924646781789639 0.7086273490362962
# (4245, 35)
# (2971, 35) (2971,)
# 0.902668759811617 0.7408621259041697
# (4245, 35)
# (2971, 35) (2971,)
# 0.8971742543171115 0.7195816596232714
# (4245, 35)
# (2971, 35) (2971,)
# 0.8924646781789639 0.7234378627707846
# (4245, 35)
# (2971, 35) (2971,)
# 0.8979591836734694 0.725813087631471
# (4245, 35)
# (2971, 35) (2971,)
# 0.8979591836734694 0.7323869882532876
# (4245, 35)
# (2971, 35) (2971,)
# 0.8979591836734694 0.7174821335261615
# (4245, 35)
# (2971, 35) (2971,)
# 0.8885400313971743 0.6996097946056872
# [0.8924646781789639, 0.8924646781789639, 0.902668759811617, 0.8971742543171115, 0.8924646781789639, 0.8979591836734694, 0.8979591836734694, 0.8979591836734694, 0.8885400313971743]
# 0.902668759811617
# 2
# 0.7408621259041697

# %%
avgaccs=[]
avgmccs=[]
for i in range(1,36):
  features2 = hind_df.iloc[:,F[0:i]].to_numpy()
  acc,mcc=[],[]
  for j in range(0,10):
    X_train, y_train, X_test, y_test = train_test_split(features2,target, test_size = 0.3,stratify=target)
    xg = XGBClassifier(MAX_ROUNDS,early_stopping_rounds=EARLY_STOP,maximize=True)
    xg.fit(X_train,X_test)
    pred = xg.predict(y_train)
    acc.append(accuracy_score(y_test, pred))
    mcc.append(matthews_corrcoef(y_test, pred))
  print('For ',i,'number of features: ',round(mean(acc),4)*100,round(mean(mcc),4))
  avgaccs.append(round(mean(acc),4)*100)
  avgmccs.append(round(mean(mcc),4))
print(max(avgaccs))
print(avgaccs.index(max(avgaccs)))
# Out:
# For  1 number of features:  67.30000000000001 0.08
# For  2 number of features:  71.39999999999999 0.205
# For  3 number of features:  80.13 0.4529
# For  4 number of features:  83.91999999999999 0.5612
# For  5 number of features:  84.23 0.5726
# For  6 number of features:  84.35000000000001 0.5747
# For  7 number of features:  83.95 0.5654
# For  8 number of features:  84.05 0.5684
# For  9 number of features:  84.34 0.5767
# For  10 number of features:  84.8 0.588
# For  11 number of features:  85.92 0.6219
# For  12 number of features:  87.62 0.6704
# For  13 number of features:  87.17 0.657
# For  14 number of features:  87.64999999999999 0.6693
# For  15 number of features:  89.02 0.7086
# For  16 number of features:  88.67 0.699
# For  17 number of features:  89.13 0.7115
# For  18 number of features:  89.58 0.7238
# For  19 number of features:  89.28 0.7156
# For  20 number of features:  89.19 0.7139
# For  21 number of features:  89.22 0.7144
# For  22 number of features:  88.75999999999999 0.7016
# For  23 number of features:  89.41 0.7192
# For  24 number of features:  89.4 0.7187
# For  25 number of features:  89.28 0.7161
# For  26 number of features:  89.13 0.7112
# For  27 number of features:  89.37 0.7183
# For  28 number of features:  89.3 0.7167
# For  29 number of features:  89.35 0.7181
# For  30 number of features:  89.4 0.7182
# For  31 number of features:  88.83 0.7029
# For  32 number of features:  89.39 0.7184
# For  33 number of features:  89.18 0.713
# For  34 number of features:  89.25 0.7152
# For  35 number of features:  89.4 0.7202
# 89.58
# 17
